# %% [markdown]
# Pandas case study

# %%
import pandas as pd 
import seaborn as sns
import numpy as np 
import matplotlib.pyplot as plt

# %%
kashti=sns.load_dataset("titanic")
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#saving dat set into csv file
kashti.to_csv("kashti.csv")

# %%
# write below written codee in jupyter note book
#readfile=pd.read_csv(r"C:\\Users\\Haris Bin Tariq\\Desktop\\python_for_firsttime\\pandas\\kashti.csv" )

#readfile.to_excel(r"C:\\Users\\Haris Bin Tariq\\Desktop\\python_for_firsttime\\pandas\\kashti.xlsx",index = None, header=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\HARISB~1\AppData\Local\Temp/ipykernel_4832/1040524067.py in <module>
#       1 readfile=pd.read_csv(r"C:\\Users\\Haris Bin Tariq\\Desktop\\python_for_firsttime\\pandas\\kashti.csv" )
# ----> 2 readfile.to_excel(r"C:\\Users\\Haris Bin Tariq\\Desktop\\python_for_firsttime\\pandas\\kashti.xlsx",index = None, header=True)
#
# ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2282             inf_rep=inf_rep,
#    2283         )
# -> 2284         formatter.write(
#    2285             excel_writer,
#    2286             sheet_name=sheet_name,
#
# ...

# %%
# basic stats
kashti.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
#dropping few columns and make a new data set
new_kashti=kashti.drop(["deck","embark_town","alone"],axis=1)
new_kashti.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male alive
# 0    man        True    no
# 1  woman       False   yes
# 2  woman       False   yes
# 3  woman       False   yes
# 4    man        True    no

# %%
kashti.drop(["deck","embark_town","alone"],axis=1).head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male alive
# 0    man        True    no
# 1  woman       False   yes
# 2  woman       False   yes
# 3  woman       False   yes
# 4    man        True    no

# %%
kashti.mean()
# Out:
# C:\Users\HARISB~1\AppData\Local\Temp/ipykernel_4832/3332994036.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti.mean()
# survived       0.383838
# pclass         2.308642
# age           29.699118
# sibsp          0.523008
# parch          0.381594
# fare          32.204208
# adult_male     0.602694
# alone          0.602694
# dtype: float64

# %%
kashti.groupby(["sex"]).mean()
# Out:
#         survived    pclass        age     sibsp     parch       fare  \
# sex
# female  0.742038  2.159236  27.915709  0.694268  0.649682  44.479818
# male    0.188908  2.389948  30.726645  0.429809  0.235702  25.523893
#
#         adult_male     alone
# sex
# female    0.000000  0.401274
# male      0.930676  0.712305

# %%
kashti.groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.968085     1.0  34.611765  0.553191  0.457447  106.125798
#        Second  0.921053     2.0  28.722973  0.486842  0.605263   21.970121
#        Third   0.500000     3.0  21.750000  0.895833  0.798611   16.118810
# male   First   0.368852     1.0  41.281386  0.311475  0.278689   67.226127
#        Second  0.157407     2.0  30.740707  0.342593  0.222222   19.741782
#        Third   0.135447     3.0  26.507589  0.498559  0.224784   12.661633
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.361702
#        Second    0.000000  0.421053
#        Third     0.000000  0.416667
# male   First     0.975410  0.614754
#        Second    0.916667  0.666667
#        Third     0.919308  0.760807

# %%
#children and women to save at earliest
kashti[kashti["age"]<18].mean()
# Out:
# C:\Users\HARISB~1\AppData\Local\Temp/ipykernel_4832/2427175337.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   kashti[kashti["age"]<18].mean()
# survived       0.539823
# pclass         2.584071
# age            9.041327
# sibsp          1.460177
# parch          1.053097
# fare          31.220798
# adult_male     0.159292
# alone          0.203540
# dtype: float64

# %%
#children
kashti[kashti["age"]<18].groupby(["sex","class"]).mean()
# Out:
#                survived  pclass        age     sibsp     parch        fare  \
# sex    class
# female First   0.875000     1.0  14.125000  0.500000  0.875000  104.083337
#        Second  1.000000     2.0   8.333333  0.583333  1.083333   26.241667
#        Third   0.542857     3.0   8.428571  1.571429  1.057143   18.727977
# male   First   1.000000     1.0   8.230000  0.500000  2.000000  116.072900
#        Second  0.818182     2.0   4.757273  0.727273  1.000000   25.659473
#        Third   0.232558     3.0   9.963256  2.069767  1.000000   22.752523
#
#                adult_male     alone
# sex    class
# female First     0.000000  0.125000
#        Second    0.000000  0.166667
#        Third     0.000000  0.228571
# male   First     0.250000  0.000000
#        Second    0.181818  0.181818
#        Third     0.348837  0.232558
