# %%
import pandas as pd
 #import data from file
chilla=pd.read_csv("assignment_plots.csv")
#print(chilla)
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
#p=sns.lineplot(x="Gender",hue="Age",data=chilla)
#p=sns.countplot(x="Qualification_completed",hue="field_of_study",data=chilla)
p=sns.countplot(x="field_of_study",hue="Purpose_for_chilla",data=chilla)
plt.show()

# %%
import pandas as pd
 #import data from file
chilla=pd.read_csv("assignment_plots.csv")
#print(chilla)
import seaborn as sns
from numpy import mean
import matplotlib.pyplot as plt
sns.set_theme(style="ticks", color_codes=True)
plt.figure(figsize=(10,8))
#p=sns.lineplot(x="Gender",hue="Age",data=chilla)
#p=sns.countplot(x="Qualification_completed",hue="field_of_study",data=chilla)
p=sns.countplot(x="field_of_study",hue="Age",data=chilla,color="red",
               palette="pastel")
plt.show()
