# %%
#Import librairies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data from file
chilla=pd.read_csv("FnAgri_data.csv")
chilla.head()
# Out:
#   Domain Code              Domain  Area Code (FAO)        Area  Element Code  \
# 0          QI  Production Indices               16  Bangladesh           434
# 1          QI  Production Indices               16  Bangladesh           434
# 2          QI  Production Indices               16  Bangladesh           434
# 3          QI  Production Indices               16  Bangladesh           434
# 4          QI  Production Indices               16  Bangladesh           434
#
#                                              Element  Item Code (FAO)  \
# 0  Gross per capita Production Index Number (2014...              265
# 1  Gross per capita Production Index Number (2014...              265
# 2  Gross per capita Production Index Number (2014...              265
# 3  Gross per capita Production Index Number (2014...              265
# 4  Gross per capita Production Index Number (2014...              265
#
#               Item  Year Code  Year   Unit   Value Flag Flag Description
# ...

# %%
sns.set_theme(style="ticks", color_codes=True)
#p=sns.lineplot(x="Gender",hue="Age",data=chilla)
#p=sns.countplot(x="Qualification_completed",hue="field_of_study",data=chilla)
p=sns.countplot(x="Area",hue="Item",data=chilla)
plt.show()

# %%
# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
sns.scatterplot(x="Area", y="Value",hue="Item",
                palette="ch:r=-.2,d=.3_r",
                sizes=(1, 8), linewidth=0,
                data=chilla, ax=ax)
# Out:
# <AxesSubplot:xlabel='Area', ylabel='Value'>

# %%
sns.set_theme(style="ticks")

# Define the palette as a list to specify exact values
#palette = sns.color_palette("viridis")

# Plot the lines on two facets
sns.relplot(
    data=chilla,
    x="Year", y="Item",
    hue="Area",
    kind="line", size_order=["T1", "T2"],
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
# Plot the responses for different events and regions
sns.lineplot(x="Year", y="Item",
             hue="Area",
             data=chilla)
sns.set_style("dark")
plt.title("food production") # add the title
plt.show()

# %%
#draw a barplot
sns.barplot(x="Item",y="Area Code (FAO)", hue="Area", data=chilla)

plt.title("food production")
plt.figure(figsize=(10,2))
# plt.xlim(2) #to put limit on ais
# plt.ylim(1)

plt.show()

# %%
#import data from file for cereals production in pakistan
baba=pd.read_csv("cereals_prd.csv")
baba.head()
# Out:
#   Domain Code                        Domain  Area Code      Area  \
# 0         QCL  Crops and livestock products        165  Pakistan
# 1         QCL  Crops and livestock products        165  Pakistan
# 2         QCL  Crops and livestock products        165  Pakistan
# 3         QCL  Crops and livestock products        165  Pakistan
# 4         QCL  Crops and livestock products        165  Pakistan
#
#    Element Code         Element  Item Code            Item  Year Code  Year  \
# 0          5312  Area harvested       1717  Cereals, Total       1961  1961
# 1          5419           Yield       1717  Cereals, Total       1961  1961
# 2          5510      Production       1717  Cereals, Total       1961  1961
# 3          5312  Area harvested       1717  Cereals, Total       1962  1962
# 4          5419           Yield       1717  Cereals, Total       1962  1962
#
#      Unit    Value Flag                                   Flag Description
# ...

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
# Plot the responses for different events and regions
sns.lineplot(x="Year", y="Value",
             hue="Area",color="red",
             data=baba)
sns.set_style("dark")
plt.title("cereal production") # add the title
plt.show()

# %%
baba.describe()
# Out:
#        Area Code  Element Code  Item Code    Year Code         Year  \
# count      180.0    180.000000      180.0   180.000000   180.000000
# mean       165.0   5413.666667     1717.0  1990.500000  1990.500000
# std          0.0     81.146808        0.0    17.366409    17.366409
# min        165.0   5312.000000     1717.0  1961.000000  1961.000000
# 25%        165.0   5312.000000     1717.0  1975.750000  1975.750000
# 50%        165.0   5419.000000     1717.0  1990.500000  1990.500000
# 75%        165.0   5510.000000     1717.0  2005.250000  2005.250000
# max        165.0   5510.000000     1717.0  2020.000000  2020.000000
#
#               Value
# count  1.800000e+02
# mean   1.161077e+07
# std    1.157594e+07
# min    8.400000e+03
# 25%    2.596750e+04
# 50%    1.104450e+07
# 75%    1.413153e+07
# max    4.430000e+07

# %%
#Import librairies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data from file
chilla=pd.read_csv("emp.csv")
chilla.head()
# Out:
#   Domain Code                 Domain  Area Code (FAO)        Area  \
# 0          OE  Employment Indicators               16  Bangladesh
# 1          OE  Employment Indicators               16  Bangladesh
# 2          OE  Employment Indicators               16  Bangladesh
# 3          OE  Employment Indicators               16  Bangladesh
# 4          OE  Employment Indicators               16  Bangladesh
#
#    Indicator Code                                          Indicator  \
# 0           21155  Share of employment in agriculture, forestry a...
# 1           21156  Share of employment in agriculture, forestry a...
# 2           21156  Share of employment in agriculture, forestry a...
# 3           21156  Share of employment in agriculture, forestry a...
# 4           21155  Share of employment in agriculture, forestry a...
#
#    Sex Code   Sex  Year Code  Year  Source Code                        Source  \
# ...

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")
# Plot the responses for different events and regions
sns.barplot(x="Area", y="Value",
             hue="Sex",color="red",
             data=chilla)
sns.set_style("dark")
plt.title("Employment comparison (2000~2020)") # add the title
plt.show()
