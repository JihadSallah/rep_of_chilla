# %%
#Import librairies
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#import data from file
chilla=pd.read_csv("FnAgri_data.csv")
chilla
# Out:
#     Domain Code              Domain  Area Code (FAO)        Area  \
# 0            QI  Production Indices               16  Bangladesh
# 1            QI  Production Indices               16  Bangladesh
# 2            QI  Production Indices               16  Bangladesh
# 3            QI  Production Indices               16  Bangladesh
# 4            QI  Production Indices               16  Bangladesh
# ..          ...                 ...              ...         ...
# 946          QI  Production Indices              165    Pakistan
# 947          QI  Production Indices              165    Pakistan
# 948          QI  Production Indices              165    Pakistan
# 949          QI  Production Indices              165    Pakistan
# 950          QI  Production Indices              165    Pakistan
#
#      Element Code                                            Element  \
# 0             434  Gross per capita Production Index Number (2014...
# 1             434  Gross per capita Production Index Number (2014...
# 2             434  Gross per capita Production Index Number (2014...
# 3             434  Gross per capita Production Index Number (2014...
# 4             434  Gross per capita Production Index Number (2014...
# ..            ...                                                ...
# 946           434  Gross per capita Production Index Number (2014...
# 947           434  Gross per capita Production Index Number (2014...
# 948           434  Gross per capita Production Index Number (2014...
# 949           434  Gross per capita Production Index Number (2014...
# 950           434  Gross per capita Production Index Number (2014...
#
#      Item Code (FAO)                      Item  Year Code  Year   Unit  \
# 0                265           Castor oil seed       2000  2000  index
# 1                265           Castor oil seed       2001  2001  index
# 2                265           Castor oil seed       2002  2002  index
# 3                265           Castor oil seed       2003  2003  index
# 4                265           Castor oil seed       2004  2004  index
# ..               ...                       ...        ...   ...    ...
# 946             1732  Oilcrops, Oil Equivalent       2015  2015  index
# 947             1732  Oilcrops, Oil Equivalent       2016  2016  index
# 948             1732  Oilcrops, Oil Equivalent       2017  2017  index
# 949             1732  Oilcrops, Oil Equivalent       2018  2018  index
# 950             1732  Oilcrops, Oil Equivalent       2019  2019  index
#
#       Value Flag Flag Description
# 0    130.12   Fc  Calculated data
# 1    123.12   Fc  Calculated data
# 2    120.90   Fc  Calculated data
# 3    127.63   Fc  Calculated data
# 4    129.92   Fc  Calculated data
# ..      ...  ...              ...
# 946   90.64   Fc  Calculated data
# 947   90.67   Fc  Calculated data
# 948   97.92   Fc  Calculated data
# 949   86.50   Fc  Calculated data
# 950   84.18   Fc  Calculated data
#
# [951 rows x 14 columns]

# %%
sns.set_theme(style="ticks", color_codes=True)
#p=sns.lineplot(x="Gender",hue="Age",data=chilla)
#p=sns.countplot(x="Qualification_completed",hue="field_of_study",data=chilla)
p=sns.countplot(x="Area",hue="Item",data=chilla)
plt.show()

# %%
chilla=pd.read_csv("co2.csv")
chilla
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\HARISB~1\AppData\Local\Temp/ipykernel_17480/748105514.py in <module>
# ----> 1 chilla=pd.read_csv("co2.csv")
#       2 chilla
#
# NameError: name 'pd' is not defined

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()
